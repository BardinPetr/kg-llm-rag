# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install ultralytics comet_ml
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
from datetime import datetime
import comet_ml
comet_ml.login(project_name="comet-example-yolo26-coco128")

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m-seg.pt
# Out:
# --2026-03-10 23:40:43--  https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m-seg.pt
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from ultralytics import YOLO
model = YOLO("./yolo26m-seg.pt")

# %%
results = model.train(
    data="/home/petr/study/diploma/dataset_seg_yolo/dataset_seg_yolo.yaml",
    imgsz=640,
    batch=8,
    workers=8,
    cache=True,

    epochs=100,
    patience=50,

    # lr0=0.001,
    # lrf=0.01,

    save=True,
    save_period=5,
    val=True,
    plots=True,

    # freeze=3,

    rect=False,
    hsv_h=0.0,      # HSV-Hue augmentation (fraction)
    hsv_s=0.0,        # HSV-Saturation augmentation
    hsv_v=0.0,        # HSV-Value augmentation
    degrees=0,     # Image rotation (+/- deg)
    translate=0,    # Image translation (+/- fraction)
    scale=0,        # Image scale (+/- gain)
    shear=0,        # Image shear (+/- deg)
    perspective=0.0,  # Image perspective (+/- fraction)
    flipud=0.5,       # Vertical flip (probability)
    fliplr=0.5,       # Horizontal flip (probability)
    mosaic=0,       # Mosaic augmentation (probability)
    mixup=0,        # Mixup augmentation (probability)
    cutmix=0,
    copy_paste=0,

    project=f"y26ms",
    name=f"y26ms-{datetime.now()}".replace(" ", "")
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.11 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7808MiB)
# ...

# %%
model = YOLO("/home/petr/projects/mltests/runs/segment/y26ms/y26ms-2026-03-1023:49:56.386864/weights/best.pt")
results = model.predict(
    source="/home/petr/study/diploma/src/datasetgen/demo",
    save=True,
    project="/home/petr/projects/mltests/runs/segment/y26ms/y26ms-2026-03-1023:49:56.386864",
    name='results',
    exist_ok=True,
    # conf=0.1,
    # rect=False,
    # iou=0.9
)
# Out:
# image 1/11 /home/petr/study/diploma/src/datasetgen/demo/044030790.png: 448x640 14 edges, 51.1ms
# image 2/11 /home/petr/study/diploma/src/datasetgen/demo/044525158.png: 576x640 2 edges, 48.9ms
# image 3/11 /home/petr/study/diploma/src/datasetgen/demo/044525161.png: 416x640 14 edges, 41.9ms
# image 4/11 /home/petr/study/diploma/src/datasetgen/demo/044525666.png: 416x640 23 edges, 13.0ms
# image 5/11 /home/petr/study/diploma/src/datasetgen/demo/2b1e0cda212742b2bda4e5a3b9e1ca79.png: 480x640 24 edges, 44.1ms
# image 6/11 /home/petr/study/diploma/src/datasetgen/demo/97556ba0462cf23daeb5bf11e17e9123.png: 640x480 4 edges, 40.5ms
# image 7/11 /home/petr/study/diploma/src/datasetgen/demo/9a28fdb2a2e3b51ea48454f9f1878c0b.png: 480x640 14 edges, 11.9ms
# image 8/11 /home/petr/study/diploma/src/datasetgen/demo/c5f2f963b56c01a5cfc55ad39ff72c6a.png: 480x640 44 edges, 11.5ms
# image 9/11 /home/petr/study/diploma/src/datasetgen/demo/d97d4830c63775d4234b397e19dbd7d8.png: 480x640 41 edges, 12.2ms
# ...
